# %%
from pymushra import collection_to_df
from tinydb import TinyDB
db = TinyDB("db/webmushra.json")
print(db.tables())
df = collection_to_df(db.table("w2ntest"))
df.head()
# Out:
# {'w2ntest', 'teste2', 'teste1'}
#   responses      wm                             \
#       score    type                       date
# 0        21  mushra 2024-10-15 09:45:56.557189
# 1        40  mushra 2024-10-15 09:45:56.557189
# 2        20  mushra 2024-10-15 09:45:56.557189
# 3         0  mushra 2024-10-15 09:45:56.557189
# 4        59  mushra 2024-10-15 09:45:56.557189
#
#                            questionaire  responses                       wm  \
#                                    uuid   stimulus   time            config
# 0  58614ffd-4690-4a78-a1fc-7d1e277bb1a2         C3  42255  configs/w2n.yaml
# 1  58614ffd-4690-4a78-a1fc-7d1e277bb1a2         C4  42255  configs/w2n.yaml
# 2  58614ffd-4690-4a78-a1fc-7d1e277bb1a2         C2  42255  configs/w2n.yaml
# 3  58614ffd-4690-4a78-a1fc-7d1e277bb1a2  reference  42255  configs/w2n.yaml
# 4  58614ffd-4690-4a78-a1fc-7d1e277bb1a2         C1  42255  configs/w2n.yaml
#
#                    responses
#     testId      id   comment
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = df['responses']
# Criar o gráfico de caixa (boxplot) para cada estímulo
plt.figure(figsize=(8, 6))
sns.boxplot(x='stimulus', y='score', data=df, palette='Set3')

# Adicionar título e rótulos aos eixos
plt.title('Distribuição das Pontuações por Estímulo', fontsize=14)
plt.xlabel('Estímulo', fontsize=12)
plt.ylabel('Pontuação', fontsize=12)

# Mostrar o gráfico
plt.show()
# Out:
# /tmp/ipykernel_7469/3583954903.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='stimulus', y='score', data=df, palette='Set3')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = df['responses']
# Criar o gráfico de caixa (boxplot) para cada estímulo
plt.figure(figsize=(8, 6))
sns.boxplot(x='stimulus', y='score', data=df, palette='Set3')

# Adicionar título e rótulos aos eixos
plt.title('Distribuição das Pontuações por Estímulo', fontsize=14)
plt.xlabel('Estímulo', fontsize=12)
plt.ylabel('Pontuação', fontsize=12)

# Mostrar o gráfico
plt.show()
# Out:
# /tmp/ipykernel_7469/3583954903.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='stimulus', y='score', data=df, palette='Set3')
