# %%
# !mkdir db
# !pip install -e pymushra
# Out:
# mkdir: cannot create directory ‘db’: File exists
# fatal: destination path 'webmushra' already exists and is not an empty directory.
# fatal: destination path 'pymushra' already exists and is not an empty directory.
# Obtaining file:///home/fumio/Projetos/Python/Doutorado/MUSHRA/pymushra
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: pymushra
#     Found existing installation: pymushra 0.3
#     Uninstalling pymushra-0.3:
#       Successfully uninstalled pymushra-0.3
#   Running setup.py develop for pymushra
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Install PyNgrok
# !pip install pyngrok
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Configure Ngrok and Setup Tunneling
from pyngrok import ngrok
ngrok.set_auth_token('2nQkEx4zN4WhTd08wSTouErNVsz_4qsjiGUgwp9JsE4Em3xre')
public_url = ngrok.connect(5000)
public_url.public_url += "?config=w2n.yaml"

# %%
# Print Public URL and start webMUSHRA application
print(public_url)
# !pymushra server
# Out:
# NgrokTunnel: "https://f9aa-194-38-139-101.ngrok-free.app?config=w2n.yaml" -> "http://localhost:5000"
#  * Serving Flask app 'pymushra.service'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.160.14.236:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 585-201-419
# 127.0.0.1 - - [17/Oct/2024 11:00:07] "GET /?config=w2n.yaml HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Oct/2024 11:00:08] "GET /lib/external/jquery.mobile/jquery.mobile-1.4.4.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Oct/2024 11:00:08] "GET /lib/external/jquery/jquery-2.1.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Oct/2024 11:00:08] "GET /lib/external/jquery.mobile/plugins/jQuery-Mobile-Icon-Pack/original/jqm-icon-pack-2.0-original.css HTTP/1.1" 200 -
# ...
